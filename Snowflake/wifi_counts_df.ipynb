# %%
from snowflake.snowpark import Session as sn
import pandas as pd

# Your user and password is unique to you
connector = {
    'account': 'tub49591.us-east-1',
    'user': '',
    'password': '',
    'role': 'sysadmin',
    'warehouse': 'MY_WAREHOUSE',
    'database': 'NINER_TRANSIT',
    'schema': 'wifi_counts_script'}
# Out:
# C:\Users\Willy\.conda\envs\altair install\lib\site-packages\snowflake\connector\options.py:96: UserWarning: You have an incompatible version of 'pyarrow' installed (9.0.0), please install a version that adheres to: 'pyarrow<8.1.0,>=8.0.0; extra == "pandas"'
#   warn_incompatible_dep(

# %%
query = sn.builder.configs(connector).create()

# %%
command = 'SELECT * FROM "Wifi_Counts";'
result = query.sql(command).collect()
query.close()

# %%
df = pd.DataFrame(list(result))
display(df)
# Out:
#                timestamp  Atki  Auxi  BaTF  Band  Barn  BelG  BelH  Bioi  \
# 0    2020-09-28 00:00:00    76    20    22     4     6     6   702    86
# 1    2020-09-28 01:00:00    24     8     0    38    16     0   518    14
# 2    2020-09-28 02:00:00    26    12     4    16     2     4   416    22
# 3    2020-09-28 03:00:00    32     8     8     0    78    58   398    22
# 4    2020-09-28 04:00:00    44     0     0     0    70     2   332    12
# ...                  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 8537 2021-09-28 19:00:00  3844  1740   752   516   926  7865  2112  1382
# 8538 2021-09-28 20:00:00  2876  1204  1040   570   640  4196  1958   988
# 8539 2021-09-28 21:00:00  1540   674   498   358   336   732  1840   752
# 8540 2021-09-28 22:00:00  1062   424   456   296   134   652  1456   402
# 8541 2021-09-28 23:00:00   736   214    96   236    44   620  1024   226
#
#       Burs  ...   StuU  Syca  Tenn   UREC  Unio  Wach  Wall  Winn  With  Wood
# 0       42  ...    140    10    60     90    14     8    56     2   392    60
# 1       46  ...     48    14    12     80     8    70    22    20   316     8
# 2       10  ...     22    12    56    108    16    12    16    14    22    16
# 3       46  ...     18     0    18    194     4     6     4    26    18    82
# 4       46  ...    118     4     6    276     0    24    20    30    20    24
# ...    ...  ...    ...   ...   ...    ...   ...   ...   ...   ...   ...   ...
# 8537  3306  ...  11904   522  3648  20979  1046   583  1030  1132   740  5660
# 8538  2706  ...   9298   348  2555  21942   834  1182   793  1212   566  3569
# 8539  1758  ...   5111   260  1724  18706   855   982   500   848   607  1962
# 8540   920  ...   2562   162   894   8888   434   628   360   192   486   450
# 8541   462  ...    860   134   540   1588   238    20   236   128   418   344
#
# [8542 rows x 74 columns]

# %%
# CHANGE THIS
#Create data file
filename = 'Test' + '_Data.csv'
# Remove index while writing
df.to_csv(filename, index=False)
print (filename)
# Out:
# Test_Data.csv
