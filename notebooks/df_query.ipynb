# %% [markdown]
# ## Creating a function to "query" pandas DataFrame

# %%
import pandas as pd
from datetime import datetime
import os

# %%
os.chdir('C:\\Users\\calvi\\Documents\\College\\UNCC\\Fall 2022\\ITSC 4155\\Project\\ETL')

# %%
df = pd.read_csv('data_files/wifi_counts_combined.csv')

# %%
df.timestamp = pd.to_datetime(df.timestamp)

# %%
df
# Out:
#                timestamp    Atki    Auxi    BaTF   Band   Barn    BelG  \
# 0    2020-09-28 00:00:00    76.0    20.0    22.0    4.0    6.0     6.0
# 1    2020-09-28 01:00:00    24.0     8.0     0.0   38.0   16.0     0.0
# 2    2020-09-28 02:00:00    26.0    12.0     4.0   16.0    2.0     4.0
# 3    2020-09-28 03:00:00    32.0     8.0     8.0    0.0   78.0    58.0
# 4    2020-09-28 04:00:00    44.0     0.0     0.0    0.0   70.0     2.0
# ...                  ...     ...     ...     ...    ...    ...     ...
# 8537 2021-09-28 19:00:00  3844.0  1740.0   752.0  516.0  926.0  7865.0
# 8538 2021-09-28 20:00:00  2876.0  1204.0  1040.0  570.0  640.0  4196.0
# 8539 2021-09-28 21:00:00  1540.0   674.0   498.0  358.0  336.0   732.0
# 8540 2021-09-28 22:00:00  1062.0   424.0   456.0  296.0  134.0   652.0
# 8541 2021-09-28 23:00:00   736.0   214.0    96.0  236.0   44.0   620.0
#
#         BelH    Bioi    Burs  ...     StuU   Syca    Tenn     UREC    Unio  \
# ...

# %%
filtered_df = df.query("timestamp >= '2021-09-28' and timestamp < '2021-09-29'")

# %%
from datetime import datetime, timedelta

# %%
q = datetime(year = 2021, month = 8, day = 15 )

# %%
q + timedelta(3)
# Out:
# datetime.datetime(2021, 8, 18, 0, 0)

# %%
str(q)[:-9]
# Out:
# '2021-08-15'

# %%
q = '2021-08-12'

# %%
pattern = re.compile('^\d{4}\-(0?[1-9]|1[012])\-(0?[1-9]|[12][0-9]|3[01])$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 pattern = re.compile('^\d{4}\-(0?[1-9]|1[012])\-(0?[1-9]|[12][0-9]|3[01])$')
#
# NameError: name 're' is not defined

# %%
result = re.match(pattern, q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 result = re.match(pattern, q)
#
# NameError: name 're' is not defined

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
# !pip install fastapi

# %%
import re
from fastapi import HTTPException

def validate_query(q: str):
    pattern = re.compile(r'^\d{4}\-(0?[1-9]|1[012])\-(0?[1-9]|[12][0-9]|3[01])$') #validate string is in format yyyy-mm-dd
    result = re.match(pattern, q)
    if result is None:
        raise HTTPException(status_code=400, detail = "Invalid string format for date. Should be formtted as yyyy-mm-dd")
    else:
        ymd = [int(x) for x in q.split('-')]
        return datetime(year = ymd[0], month = ymd[1], day = ymd[2])

# %%
[int(x) for x in q.split('-')]
# Out:
# [2021, 8, 12]

# %%
validate_query(q)

# %%
def query_df(date_str: str):
    
    def validate_input(q: str):
        pattern = re.compile(r'^\d{4}\-(0?[1-9]|1[012])\-(0?[1-9]|[12][0-9]|3[01])$') #validate string is in format yyyy-mm-dd
        result = re.match(pattern, q)
        if result is None:
            raise HTTPException(status_code=400, detail = "Invalid string format for date. Should be formtted as yyyy-mm-dd")
        else:
            ymd = [int(x) for x in q.split('-')]
            return datetime(year = ymd[0], month = ymd[1], day = ymd[2])
    
    date = validate_input(date_str)
    query = f"timestamp >= '{date}' and timestamp < '{date + timedelta(1)}'"
    print(query)
    return df.query(query)

# %%
query_df('2020-12-02')
# Out:
# timestamp >= '2020-12-02 00:00:00' and timestamp < '2020-12-03 00:00:00'
#                timestamp    Atki   Auxi   BaTF   Band   Barn   BelG   BelH  \
# 1560 2020-12-02 00:00:00   164.0   58.0   32.0    2.0   22.0   16.0  260.0
# 1561 2020-12-02 01:00:00   266.0   48.0    8.0   28.0   22.0    6.0  398.0
# 1562 2020-12-02 02:00:00   168.0   50.0   14.0   44.0   12.0    2.0  142.0
# 1563 2020-12-02 03:00:00   224.0   46.0    2.0   14.0   78.0  126.0   66.0
# 1564 2020-12-02 04:00:00   126.0   24.0    0.0    0.0   46.0   20.0  132.0
# 1565 2020-12-02 05:00:00   148.0   56.0   12.0    8.0   20.0   12.0   72.0
# 1566 2020-12-02 06:00:00   186.0  132.0    8.0   70.0   78.0  362.0  366.0
# 1567 2020-12-02 07:00:00   318.0  416.0   58.0   96.0  146.0  770.0  370.0
# 1568 2020-12-02 08:00:00   460.0  562.0  130.0  172.0  174.0  418.0  610.0
# 1569 2020-12-02 09:00:00   436.0  486.0  134.0  168.0  272.0  686.0  428.0
# ...

# %%
df.query(

# %%
df.iloc[8518]
